# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd
import datetime as dt

# %% [markdown]
# # Reflect Tables into SQLAlchemy ORM

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
# create engine to hawaii.sqlite
engine = create_engine("sqlite:///Resources/hawaii.sqlite")

# %%
# reflect an existing database into a new model
Base=automap_base()
# reflect the tables
Base.prepare(engine,reflect=True)

# %%
# View all of the classes that automap found
Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
# Save references to each table
Measurement=Base.classes.measurement
Station=Base.classes.station

# %%
# Create our session (link) from Python to the DB
my_session=Session(engine)
conn=engine.connect()

# %% [markdown]
# # Exploratory Precipitation Analysis

# %%
measurement_data=my_session.query(Measurement).first()
measurement_data.__dict__
# Out:
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState at 0x20f5b0b4af0>,
#  'date': '2010-01-01',
#  'id': 1,
#  'tobs': 65.0,
#  'station': 'USC00519397',
#  'prcp': 0.08}

# %%
station_data=my_session.query(Station).first()
station_data.__dict__
# Out:
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState at 0x20f5b71fb80>,
#  'id': 1,
#  'name': 'WAIKIKI 717.2, HI US',
#  'longitude': -157.8168,
#  'latitude': 21.2716,
#  'station': 'USC00519397',
#  'elevation': 3.0}

# %%
# Find the most recent date in the data set.
most_recent_m=my_session.query(func.max(Measurement.date)).scalar()
most_recent_m
# Out:
# '2017-08-23'

# %%
# Design a query to retrieve the last 12 months of precipitation data and plot the results. 
# Starting from the most recent data point in the database. 
# Calculate the date one year from the last date in data set.
query_date = dt.date(2017, 8, 23) - dt.timedelta(days=365)
print(query_date)

# Perform a query to retrieve the data and precipitation scores
last_year=my_session.query(Measurement.date,Measurement.prcp).\
    filter(Measurement.date>=query_date).all()

# Save the query results as a Pandas DataFrame and set the index to the date column
one_year=pd.DataFrame(last_year)

one_year.rename(columns={0:'date',1:'precipitation'}, inplace=True)
one_year.set_index('date', inplace=True) 

# Sort the dataframe by date
one_year.sort_index(inplace=True)
one_year.head()

# Use Pandas Plotting with Matplotlib to plot the data
one_year.plot(figsize=(12,8))
plt.show()
# Out:
# 2016-08-23

# %%
# Use Pandas to calcualte the summary statistics for the precipitation data
one_year.describe()
# Out:
#        precipitation
# count    2021.000000
# mean        0.177279
# std         0.461190
# min         0.000000
# 25%         0.000000
# 50%         0.020000
# 75%         0.130000
# max         6.700000

# %% [markdown]
# # Exploratory Station Analysis

# %%
# Design a query to calculate the total number stations in the dataset
total=my_session.query(Station).count()
total
# Out:
# 9

# %%
# Design a query to find the most active stations (i.e. what stations have the most rows?)
# List the stations and the counts in descending order.
most_active=my_session.query(Measurement.station,func.count(Measurement.station)).\
    filter(Station.station==Measurement.station).group_by(Measurement.station).\
    order_by(func.count(Station.station).desc()).all()
most_active
# Out:
# [('USC00519281', 2772),
#  ('USC00519397', 2724),
#  ('USC00513117', 2709),
#  ('USC00519523', 2669),
#  ('USC00516128', 2612),
#  ('USC00514830', 2202),
#  ('USC00511918', 1979),
#  ('USC00517948', 1372),
#  ('USC00518838', 511)]

# %%
# Using the most active station id from the previous query, calculate the lowest, highest, and average temperature.
lowest_H_A=my_session.query(func.min(Measurement.tobs),func.max(Measurement.tobs),func.avg(Measurement.tobs)).filter(Measurement.station=='USC00519281').first()
lowest_H_A
# Out:
# (54.0, 85.0, 71.66378066378067)

# %%
# Using the most active station id
# Query the last 12 months of temperature observation data for this station and plot the results as a histogram
last_year_tem=my_session.query(Measurement.date,Measurement.tobs).\
    filter(Measurement.date>=query_date,Measurement.station=='USC00519281').all()
last_year_tem

one_year_tem=pd.DataFrame(last_year_tem)
one_year_tem.rename(columns={0:'date',1:'temperature'}, inplace=True)
one_year_tem.set_index('date', inplace=True) 
one_year_tem.sort_index(inplace=True)
one_year_tem.head()

one_year_tem.plot.hist(figsize=(12,8))
plt.show()

# %% [markdown]
# # Close session

# %%
# Close Session
my_session.close()
